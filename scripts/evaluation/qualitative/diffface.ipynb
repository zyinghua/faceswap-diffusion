# %%
# !git clone https://github.com/hxngiee/DiffFace.git
# %cd DiffFace
# Out:
# Cloning into 'DiffFace'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 135 (delta 8), reused 4 (delta 4), pack-reused 109 (from 1)
# Receiving objects: 100% (135/135), 9.14 MiB | 42.34 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/DiffFace/DiffFace

# %%
# !pip install torch==1.10.0 torchvision==0.11.0 torchaudio==0.10.0
# !pip install -r requirements.txt
# !pip install blobfile mpi4py
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.10.0 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for torch==1.10.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p checkpoints

# !cp /content/drive/MyDrive/Arcface.tar ./checkpoints/
# !cp /content/drive/MyDrive/FaceParser.pth ./checkpoints/
# !cp /content/drive/MyDrive/GazeEstimator.pt ./checkpoints/
# !cp /content/drive/MyDrive/Model.pt ./checkpoints/

# !ls -lh checkpoints/

# need to download pretrained weights!!
# Out:
# Mounted at /content/drive
# total 2.9G
# -rw------- 1 root root 732M Dec  8 06:10 Arcface.tar
# -rw------- 1 root root  51M Dec  8 06:10 FaceParser.pth
# -rw------- 1 root root  30M Dec  8 06:10 GazeEstimator.pt
# -rw------- 1 root root 2.1G Dec  8 06:10 Model.pt

# %%
from google.colab import files
import os

os.makedirs('data/src', exist_ok=True)
os.makedirs('data/targ', exist_ok=True)

print("Upload source images:")
uploaded_src = files.upload()
for filename in uploaded_src.keys():
    # !mv {filename} data/src/

print("\n Upload target images:")
uploaded_targ = files.upload()
for filename in uploaded_targ.keys():
    # !mv {filename} data/targ/


print("\nSource images:")
# !ls data/src/
print("\nTarget images:")
# !ls data/targ/
# Out:
# Upload source images:
#      <input type="file" id="files-e2cabd4d-d84a-4dff-9591-26428ed3e13d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2cabd4d-d84a-4dff-9591-26428ed3e13d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python main.py --output_path output/results
# Out:
# RuntimeError: module compiled against ABI version 0x1000009 but this version of numpy is 0x2000000
# Traceback (most recent call last):
#   File "/content/DiffFace/DiffFace/main.py", line 1, in <module>
#     from optimization.image_editor import ImageEditor
#   File "/content/DiffFace/DiffFace/optimization/image_editor.py", line 2, in <module>
#     import cv2
#   File "/usr/local/lib/python3.12/dist-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/usr/local/lib/python3.12/dist-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ImportError: numpy.core.multiarray failed to import
